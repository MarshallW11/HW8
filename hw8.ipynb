# %%
import onnx

# %%
model = onnx.load("hair_classifier_v1.onnx")
graph = model.graph

print("Inputs:")
for inp in graph.input:
    print(inp.name)

print("\nOutputs:")
for out in graph.output:
    print(out.name)
# Out:
# Inputs:
# input
#
# Outputs:
# output
